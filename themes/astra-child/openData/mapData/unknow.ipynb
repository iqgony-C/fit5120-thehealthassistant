# %%
#conda install -c conda-forge folium
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
from folium.plugins import Search
#from folium import plugins
 
print(folium.__version__)
 
# define the world map
world_map = folium.Map()
# display world map
world_map
# Out:
# unknown
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d6c0d575c78c44889a3a2b7690224194%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d6c0d575c78c44889a3a2b7690224194%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d6c0d575c78c44889a3a2b7690224194%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d6c0d575c78c44889a3a2b7690224194%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %%
# define the national map
national_map = folium.Map(location=[-38.043995, 145.264296], zoom_start=4)
# display national map
national_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4a854d4fa66245caa7f5bf949789699a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4a854d4fa66245caa7f5bf949789699a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4a854d4fa66245caa7f5bf949789699a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4a854d4fa66245caa7f5bf949789699a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B-38.043995%2C%20145.264296%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# make marker
bj_map = folium.Map(location=[-38.043995, 145.264296], zoom_start=10)

folium.Marker(
    location=[-38.043995, 145.264296],
    popup='playground',
    icon=folium.Icon(icon='cloud')
).add_to(bj_map)

folium.Marker(
    location=[-39.043995, 145.264296],
    popup='Timberline Lodge',
    icon=folium.Icon(color='green')
).add_to(bj_map)

folium.Marker(
    location=[-37.043995, 145.264296],
    popup='public park',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(bj_map)

bj_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_bd4ce1f4107542c5bf77b91e07ebc001%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_bd4ce1f4107542c5bf77b91e07ebc001%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_bd4ce1f4107542c5bf77b91e07ebc001%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_bd4ce1f4107542c5bf77b91e07ebc001%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B-38.043995%2C%20145.264296%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
import pandas as pd

# %% [markdown]
# ### data1

# %%
data = pd.read_csv('Basketball_Courts ACT.csv')
data.head()
# Out:
#        ID          TYPE  DIVISION                              LOCATION  \
# 0  Bskt45  Double Court    Wright      Porter Street Neighbourhood Park
# 1   Bskt2  Single Court   Ainslie                       Corroboree Park
# 2  Bskt14  Single Court    Deakin    Lawley Street - Neighbourhood Park
# 3  Bskt11  Single Court     Flynn  Blackwell Circuit Neighbourhood Park
# 4  Bskt39  Single Court  Nicholls    Lyrebird Place Pedestrian Parkland
#
#    IMAGE_LINK  VIDEO_LINK   LATITUDE   LONGITUDE                Location_1
# 0         NaN         NaN -35.311400  149.028152    (-35.3114, 149.028152)
# 1         NaN         NaN -35.268338  149.141855  (-35.268338, 149.141855)
# 2         NaN         NaN -35.319147  149.100659  (-35.319147, 149.100659)
# 3         NaN         NaN -35.206624  149.038999  (-35.206624, 149.038999)
# 4         NaN         NaN -35.193455  149.106676  (-35.193455, 149.106676)

# %%
data.columns
# Out:
# Index(['ID', 'TYPE', 'DIVISION', 'LOCATION', 'IMAGE_LINK', 'VIDEO_LINK',
#        'LATITUDE', 'LONGITUDE', 'Location_1'],
#       dtype='object')

# %%
# We do not require all the fields in the data, so let us filter it
df1 = data.filter(["LOCATION","LONGITUDE","LATITUDE"])
df1.head()
# Out:
#                                LOCATION   LONGITUDE   LATITUDE
# 0      Porter Street Neighbourhood Park  149.028152 -35.311400
# 1                       Corroboree Park  149.141855 -35.268338
# 2    Lawley Street - Neighbourhood Park  149.100659 -35.319147
# 3  Blackwell Circuit Neighbourhood Park  149.038999 -35.206624
# 4    Lyrebird Place Pedestrian Parkland  149.106676 -35.193455

# %% [markdown]
# ### data 2

# %%
data2 = pd.read_csv('ballaratplaygrounds.csv')
data2.head()
# Out:
#          Area     ID Constructed  \
# 0   Alfredton  37171   2021/9/30
# 1  Black Hill  37173   2021/9/30
# 2  Brown Hill  37174   2021/9/30
# 3   Buninyong  37175   2021/9/30
# 4   Delacombe  37176   2021/9/30
#
#                                             Location  \
# 0  Play Equipment - Alfredton Pre School, 6-8 Bal...
# 1  Play Equipment - Black Hill Pre School, 602 Sh...
# 2  Play Equipment - Brown Hill Pre School, 1 Reid...
# 3   Play Equipment - Buninyong Early Learning Centre
# 4              Play Equipment - Delacombe Pre School
#
#                       PlayType Maintain                             Site  \
# 0  PG-Child Minding Playground   Tenant             Alfredton Pre School
# 1  PG-Child Minding Playground   Tenant            Black Hill Pre School
# 2  PG-Child Minding Playground   Tenant            Brown Hill Pre School
# 3  PG-Child Minding Playground   Tenant  Buninyong Early Learning Centre
# 4  PG-Child Minding Playground   Tenant       Delacombe Childrens Centre
#
#       Ward        long        lat
# 0    North  143.806568 -37.552233
# 1  Central  143.869738 -37.548305
# 2  Central  143.895176 -37.551549
# 3    South  143.887896 -37.650429
# 4    South  143.818748 -37.580126

# %%
data2.columns
# Out:
# Index(['Area', 'ID', 'Constructed', 'Location', 'PlayType', 'Maintain', 'Site',
#        'Ward', 'long', 'lat'],
#       dtype='object')

# %%
# We do not require all the fields in the data, so let us filter it
df2 = data2.filter(["Area","long","lat"])
df2.head()
# Out:
#          Area        long        lat
# 0   Alfredton  143.806568 -37.552233
# 1  Black Hill  143.869738 -37.548305
# 2  Brown Hill  143.895176 -37.551549
# 3   Buninyong  143.887896 -37.650429
# 4   Delacombe  143.818748 -37.580126

# %%
#Create a map for data1&2
m = folium.Map(location=[-38.043995, 145.264296], control_scale=True, zoom_start=6,attr = "text some")
df1_copy = df.copy()
df2_copy = df2.copy()
fg = folium.FeatureGroup()    

# loop through data to create Marker for each hospital
for i in range(0,len(df1_copy)):
    
    
    folium.Marker(
    location=[df_copy.iloc[i]['LATITUDE'], df_copy.iloc[i]['LONGITUDE']],
    #popup="Playground",
    tooltip=str(df_copy.iloc[i]['LOCATION']),
    icon=folium.Icon(color='green',icon='info-sign'),
    ).add_to(fg)
   

for i in range(0,len(df2_copy)):
    
    
    folium.Marker(
    location=[df2_copy.iloc[i]['lat'], df2_copy.iloc[i]['long']],
    #popup="Playground",
    tooltip=str(df2_copy.iloc[i]['Area']),
    icon=folium.Icon(color='green',icon='info-sign'),
    ).add_to(fg)        


    fg.add_to(m)
Search(fg).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_acaedd6b91ad40c5b7ff6430d50cf85e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet-search%402.9.7/dist/leaflet-search.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet-search%402.9.7/dist/leaflet-search.min.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_acaedd6b91ad40c5b7ff6430d50cf85e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_acaedd6b91ad40c5b7ff6430d50cf85e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20 ...

# %%
#pip install git+https://github.com/ghandic/folium.git@search-features
# Out:
# Collecting git+https://github.com/ghandic/folium.git@search-featuresNote: you may need to restart the kernel to use updated packages.
#   Running command git clone -q https://github.com/ghandic/folium.git 'C:\Users\Windows\AppData\Local\Temp\pip-req-build-vqq4ro4d'
#   ERROR: Error [WinError 2] 系统找不到指定的文件。 while executing command git clone -q https://github.com/ghandic/folium.git 'C:\Users\Windows\AppData\Local\Temp\pip-req-build-vqq4ro4d'
# ERROR: Cannot find command 'git' - do you have 'git' installed and in your PATH?
#   Cloning https://github.com/ghandic/folium.git (to revision search-features) to c:\users\windows\appdata\local\temp\pip-req-build-vqq4ro4d

# %%
#check
df2_copy = df.copy()
df2_copy
# Out:
#                                     LOCATION   LONGITUDE   LATITUDE
# 0           Porter Street Neighbourhood Park  149.028152 -35.311400
# 1                            Corroboree Park  149.141855 -35.268338
# 2         Lawley Street - Neighbourhood Park  149.100659 -35.319147
# 3       Blackwell Circuit Neighbourhood Park  149.038999 -35.206624
# 4         Lyrebird Place Pedestrian Parkland  149.106676 -35.193455
# 5      Devonport Street - Neighbourhood Park  149.073916 -35.336639
# 6           Alston Street Neighbourhood Park  149.122054 -35.421280
# 7     Hawkesworth Place - Neighbourhood Park  149.129002 -35.408123
# 8             Lake Tuggeranong District Park  149.071724 -35.402904
# 9          Rundle Place - Neighbourhood Park  149.062246 -35.372251
# 10           River Street Neighbourhood Park  149.227383 -35.341884
# 11                 John Knight Memorial Park  149.074645 -35.237826
# 12        Hannah Place - Pedestrian Parkland  149.105790 -35.314768
# 13        Cockle Street  Pedestrian Parkland  149.113599 -35.264871
# 14          Packham Place Neighbourhood Park  149.038737 -35.201965
# 15  Boddington Crescent - Neighbourhood Park  149.051935 -35.389103
# 16      Nemarang Crescent Neighbourhood Park  149.063593 -35.357267
# 17       Kingston Street Pedestrian Parkland  149.077357 -35.209532
# 18                   Point Hut District Park  149.084235 -35.456377
# 19                       Coree - Cotter Road  148.941168 -35.323883
# 20        Burgoyne Street Neighbourhood Park  149.071640 -35.426712
# 21          Malara Street Neighbourhood Park  149.061227 -35.350207
# 22        Dillon Close - Pedestrian Parkland  149.053683 -35.337649
# 23           Helby Street Neighbourhood Park  149.160242 -35.207980
# 24    Sandalwood Street - Neighbourhood Park  149.152879 -35.316660
# 25                          Kootara Crescent  149.151911 -35.330285
# 26   Mulligans Flat Road Pedestrian Parkland  149.150881 -35.157396
# 27     Cargelligo Street Pedestrian Parkland  149.030598 -35.334126
# 28                      Kambah District Park  149.062122 -35.392426
# 29           Shann Place  Neighbourhood Park  149.077012 -35.352159
# 30                      Kambah District Park  149.062302 -35.392427
# 31    Boddington Crescent Neighbourhood Park  149.052571 -35.383505
# 32        Brennan Street  Neighbourhood Park  149.165685 -35.253398
# 33       Lansell Circuit Pedestrian Parkland  149.103042 -35.404784
# 34      Amy Ackman Street Neighbourhood Park  149.143869 -35.167850
# 35         Bettong Avenue Neighbourhood Park  149.162369 -35.188035
# 36         Griffin Place Pedestrian Parkland  149.083038 -35.418688
# 37    Clyde Finlay Street Neighbourhood Park  149.001871 -35.208530
# 38                Lambert Place - Road Verge  149.120967 -35.247334
# 39     Percy Pegg Circuit Neighbourhood Park  149.017748 -35.188399
# 40       Gadali Crescent Pedestrian Parkland  149.119613 -35.180051
# 41                      Edison District Park  149.091642 -35.339862
# 42     Attiwell Circuit - Neighbourhood Park  149.053236 -35.377732
# 43       City Youth Centre Basket Ball Court  149.134538 -35.277923
# 44                     Yerrabi District Park  149.129916 -35.179882

# %%
# save map
outputmap = "findplaygrounds_map.html"
m.save(outputmap)
